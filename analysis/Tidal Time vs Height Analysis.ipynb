# %% [markdown]
# # Initial Notebook for Tidal Time versus height analysis

# %% [markdown]
# ##Initialize Packages

# %%
import requests
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# The following ensures that the plots are in the notebook
# %matplotlib inline
import datetime  
import calendar  
import os
from datetime import datetime

# %%
data = pd.read_csv('../Data/PortTownsend2014.csv', parse_dates=['Date Time'])

# %%
data.head()
# Out:
#    Unnamed: 0           Date Time   Water Level   Sigma   O   F   R   L  \
# 0           0 2014-01-01 00:00:00         6.875   0.036   0   0   0   0
# 1           1 2014-01-01 00:06:00         6.668   0.043   0   0   0   0
# 2           2 2014-01-01 00:12:00         6.452   0.033   0   0   0   0
# 3           3 2014-01-01 00:18:00         6.222   0.036   0   0   0   0
# 4           4 2014-01-01 00:24:00         6.005   0.036   0   0   0   0
#
#    Quality
# 0         v
# 1         v
# 2         v
# 3         v
# 4         v

# %%
data_datetime = pd.DatetimeIndex(data['Date Time'])
data[' Water Level'].groupby(data_datetime.date).mean().plot().grid()
